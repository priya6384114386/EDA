# %%
import pandas as pd 
import numpy as np 
df=pd.read_csv(r"C:\Users\Dharshini\Downloads\EV_Dataset.csv")
df.head()
# Out:
#      Year Month_Name      Date           State         Vehicle_Class  \
# 0  2014.0        jan  1/1/2014  Andhra Pradesh       ADAPTED VEHICLE
# 1  2014.0        jan  1/1/2014  Andhra Pradesh  AGRICULTURAL TRACTOR
# 2  2014.0        jan  1/1/2014  Andhra Pradesh             AMBULANCE
# 3  2014.0        jan  1/1/2014  Andhra Pradesh   ARTICULATED VEHICLE
# 4  2014.0        jan  1/1/2014  Andhra Pradesh                   BUS
#
#   Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# 0           Others       Others                0.0
# 1           Others       Others                0.0
# 2           Others       Others                0.0
# 3           Others       Others                0.0
# 4              Bus          Bus                0.0

# %%
df.isnull().sum()
# Out:
# Year                 0
# Month_Name           0
# Date                 0
# State                0
# Vehicle_Class        0
# Vehicle_Category     0
# Vehicle_Type         0
# EV_Sales_Quantity    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Year', 'Month_Name', 'Date', 'State', 'Vehicle_Class',
#        'Vehicle_Category', 'Vehicle_Type', 'EV_Sales_Quantity'],
#       dtype='object')

# %%
df = df.replace({"State": {"Andhra Pradesh": np.nan}})

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3457
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          Year Month_Name       Date                     State  \
# 0      2014.0        jan   1/1/2014                       NaN
# 1      2014.0        jan   1/1/2014                       NaN
# 2      2014.0        jan   1/1/2014                       NaN
# 3      2014.0        jan   1/1/2014                       NaN
# 4      2014.0        jan   1/1/2014                       NaN
# ...       ...        ...        ...                       ...
# 96840  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96841  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96842  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96843  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96844  2023.0        dec  12/1/2023  Andaman & Nicobar Island
#
#                            Vehicle_Class Vehicle_Category Vehicle_Type  \
# 0                        ADAPTED VEHICLE           Others       Others
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96845 entries, 0 to 96844
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               96845 non-null  float64
#  1   Month_Name         96845 non-null  object
#  2   Date               96845 non-null  object
#  3   State              93388 non-null  object
#  4   Vehicle_Class      96845 non-null  object
#  5   Vehicle_Category   96845 non-null  object
#  6   Vehicle_Type       96845 non-null  object
#  7   EV_Sales_Quantity  96845 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 5.9+ MB

# %%
df.head(50)
# Out:
#       Year Month_Name      Date              State  \
# 0   2014.0        jan  1/1/2014                NaN
# 1   2014.0        jan  1/1/2014                NaN
# 2   2014.0        jan  1/1/2014                NaN
# 3   2014.0        jan  1/1/2014                NaN
# 4   2014.0        jan  1/1/2014                NaN
# 5   2014.0        jan  1/1/2014                NaN
# 6   2014.0        jan  1/1/2014                NaN
# 7   2014.0        jan  1/1/2014                NaN
# 8   2014.0        jan  1/1/2014                NaN
# 9   2014.0        jan  1/1/2014                NaN
# 10  2014.0        jan  1/1/2014                NaN
# 11  2014.0        jan  1/1/2014                NaN
# 12  2014.0        jan  1/1/2014                NaN
# 13  2014.0        jan  1/1/2014                NaN
# 14  2014.0        jan  1/1/2014                NaN
# 15  2014.0        jan  1/1/2014                NaN
# 16  2014.0        jan  1/1/2014                NaN
# ...

# %%
df.shape
# Out:
# (96845, 8)

# %%
df[["State"]]
# Out:
#                           State
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 96840  Andaman & Nicobar Island
# 96841  Andaman & Nicobar Island
# 96842  Andaman & Nicobar Island
# 96843  Andaman & Nicobar Island
# 96844  Andaman & Nicobar Island
#
# [96845 rows x 1 columns]

# %%
df[(df["Vehicle_Category"] == "Others") & (df["Vehicle_Type"] == "Others")]
# Out:
#          Year Month_Name       Date                     State  \
# 0      2014.0        jan   1/1/2014                       NaN
# 1      2014.0        jan   1/1/2014                       NaN
# 2      2014.0        jan   1/1/2014                       NaN
# 3      2014.0        jan   1/1/2014                       NaN
# 5      2014.0        jan   1/1/2014                       NaN
# ...       ...        ...        ...                       ...
# 96825  2023.0        dec  12/1/2023                       Goa
# 96829  2023.0        dec  12/1/2023                       Goa
# 96834  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96835  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96836  2023.0        dec  12/1/2023  Andaman & Nicobar Island
#
#                         Vehicle_Class Vehicle_Category Vehicle_Type  \
# 0                     ADAPTED VEHICLE           Others       Others
# 1                AGRICULTURAL TRACTOR           Others       Others
# ...

# %%
df[(df["Vehicle_Category"] == "Others") & (df["Vehicle_Type"] == "Others") & (df["Month_Name"] == "jan")]
# Out:
#         Year Month_Name      Date      State                  Vehicle_Class  \
# 0     2014.0        jan  1/1/2014        NaN                ADAPTED VEHICLE
# 1     2014.0        jan  1/1/2014        NaN           AGRICULTURAL TRACTOR
# 2     2014.0        jan  1/1/2014        NaN                      AMBULANCE
# 3     2014.0        jan  1/1/2014        NaN            ARTICULATED VEHICLE
# 5     2014.0        jan  1/1/2014        NaN                       CASH VAN
# ...      ...        ...       ...        ...                            ...
# 8848  2024.0        jan  1/1/2024  Karnataka           TRACTOR (COMMERCIAL)
# 8849  2024.0        jan  1/1/2024  Karnataka         TRAILER (AGRICULTURAL)
# 8850  2024.0        jan  1/1/2024  Karnataka           TRAILER (COMMERCIAL)
# 8851  2024.0        jan  1/1/2024  Karnataka  VEHICLE FITTED WITH GENERATOR
# 8852  2024.0        jan  1/1/2024  Karnataka        VEHICLE FITTED WITH RIG
#
#      Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# ...

# %%
df.loc[(df["Vehicle_Category"] == "Others") & 
   (df["Vehicle_Type"] == "Others") & 
   (df["Month_Name"] == "jan"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3251
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#         Year Month_Name      Date State                  Vehicle_Class  \
# 4     2014.0        jan  1/1/2014   NaN                            BUS
# 7     2014.0        jan  1/1/2014   NaN    EDUCATIONAL INSTITUTION BUS
# 13    2014.0        jan  1/1/2014   NaN                M-CYCLE/SCOOTER
# 14    2014.0        jan  1/1/2014   NaN                      MOTOR CAB
# 15    2014.0        jan  1/1/2014   NaN                      MOTOR CAR
# 16    2014.0        jan  1/1/2014   NaN                       OMNI BUS
# 19    2014.0        jan  1/1/2014   NaN      THREE WHEELER (PASSENGER)
# 765   2015.0        jan  1/1/2015   NaN                            BUS
# 768   2015.0        jan  1/1/2015   NaN    EDUCATIONAL INSTITUTION BUS
# 774   2015.0        jan  1/1/2015   NaN                M-CYCLE/SCOOTER
# 775   2015.0        jan  1/1/2015   NaN  M-CYCLE/SCOOTER-WITH SIDE CAR
# 776   2015.0        jan  1/1/2015   NaN                      MOTOR CAB
# ...

# %%
df.loc[(df["Vehicle_Category"] == "Bus") & 
   (df["Vehicle_Type"] == "Bus") & 
   (df["Month_Name"] == "jan"), "State"] = "Assam"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3227
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#         Year Month_Name      Date State                  Vehicle_Class  \
# 7     2014.0        jan  1/1/2014   NaN    EDUCATIONAL INSTITUTION BUS
# 13    2014.0        jan  1/1/2014   NaN                M-CYCLE/SCOOTER
# 14    2014.0        jan  1/1/2014   NaN                      MOTOR CAB
# 15    2014.0        jan  1/1/2014   NaN                      MOTOR CAR
# 19    2014.0        jan  1/1/2014   NaN      THREE WHEELER (PASSENGER)
# 768   2015.0        jan  1/1/2015   NaN    EDUCATIONAL INSTITUTION BUS
# 774   2015.0        jan  1/1/2015   NaN                M-CYCLE/SCOOTER
# 775   2015.0        jan  1/1/2015   NaN  M-CYCLE/SCOOTER-WITH SIDE CAR
# 776   2015.0        jan  1/1/2015   NaN                      MOTOR CAB
# 777   2015.0        jan  1/1/2015   NaN                      MOTOR CAR
# 782   2015.0        jan  1/1/2015   NaN      THREE WHEELER (PASSENGER)
# 1508  2016.0        jan  1/1/2016   NaN    EDUCATIONAL INSTITUTION BUS
# ...

# %%
df.loc[(df["Vehicle_Class"] == "THREE WHEELER(PERSONAL)") &
      (df["Vehicle_Type"] == "3W_Personal") &
      (df["Month_Name"] == "jan"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3227
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df.loc[(df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0])) &
       (df["Vehicle_Category"] == "4-Wheelers") &
      (df["Month_Name"] == "feb") , "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3211
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df.loc[(df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0])) &
       (df["Vehicle_Category"] == "4-Wheelers") &
      (df["Month_Name"] == "jan") , "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3195
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df.loc[(df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0])) &
       (df["Vehicle_Category"] == "4-Wheelers") &
      (df["Month_Name"] == "mar") , "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3179
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#         Year Month_Name      Date State                  Vehicle_Class  \
# 7     2014.0        jan  1/1/2014   NaN    EDUCATIONAL INSTITUTION BUS
# 13    2014.0        jan  1/1/2014   NaN                M-CYCLE/SCOOTER
# 19    2014.0        jan  1/1/2014   NaN      THREE WHEELER (PASSENGER)
# 768   2015.0        jan  1/1/2015   NaN    EDUCATIONAL INSTITUTION BUS
# 774   2015.0        jan  1/1/2015   NaN                M-CYCLE/SCOOTER
# 775   2015.0        jan  1/1/2015   NaN  M-CYCLE/SCOOTER-WITH SIDE CAR
# 782   2015.0        jan  1/1/2015   NaN      THREE WHEELER (PASSENGER)
# 1508  2016.0        jan  1/1/2016   NaN    EDUCATIONAL INSTITUTION BUS
# 1514  2016.0        jan  1/1/2016   NaN                M-CYCLE/SCOOTER
# 1522  2016.0        jan  1/1/2016   NaN      THREE WHEELER (PASSENGER)
# 2294  2017.0        jan  1/1/2017   NaN    EDUCATIONAL INSTITUTION BUS
# 2301  2017.0        jan  1/1/2017   NaN                M-CYCLE/SCOOTER
# ...

# %%
df[df["State"].isna()].tail(50)
# Out:
#          Year Month_Name       Date State                      Vehicle_Class  \
# 95227  2022.0        dec  12/1/2022   NaN                          FORK LIFT
# 95228  2022.0        dec  12/1/2022   NaN                      GOODS CARRIER
# 95229  2022.0        dec  12/1/2022   NaN                          HARVESTER
# 95230  2022.0        dec  12/1/2022   NaN                           MAXI CAB
# 95231  2022.0        dec  12/1/2022   NaN                    M-CYCLE/SCOOTER
# 95232  2022.0        dec  12/1/2022   NaN      M-CYCLE/SCOOTER-WITH SIDE CAR
# 95233  2022.0        dec  12/1/2022   NaN                              MOPED
# 95234  2022.0        dec  12/1/2022   NaN                          MOTOR CAB
# 95235  2022.0        dec  12/1/2022   NaN                          MOTOR CAR
# 95236  2022.0        dec  12/1/2022   NaN  MOTOR CYCLE/SCOOTER-USED FOR HIRE
# 95237  2022.0        dec  12/1/2022   NaN        MOTORISED CYCLE (CC > 25CC)
# ...

# %%
df.loc[(df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0])) &
       (df["Vehicle_Category"] == "Others"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                1103
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#         Year Month_Name      Date State                  Vehicle_Class  \
# 7     2014.0        jan  1/1/2014   NaN    EDUCATIONAL INSTITUTION BUS
# 13    2014.0        jan  1/1/2014   NaN                M-CYCLE/SCOOTER
# 19    2014.0        jan  1/1/2014   NaN      THREE WHEELER (PASSENGER)
# 768   2015.0        jan  1/1/2015   NaN    EDUCATIONAL INSTITUTION BUS
# 774   2015.0        jan  1/1/2015   NaN                M-CYCLE/SCOOTER
# 775   2015.0        jan  1/1/2015   NaN  M-CYCLE/SCOOTER-WITH SIDE CAR
# 782   2015.0        jan  1/1/2015   NaN      THREE WHEELER (PASSENGER)
# 1508  2016.0        jan  1/1/2016   NaN    EDUCATIONAL INSTITUTION BUS
# 1514  2016.0        jan  1/1/2016   NaN                M-CYCLE/SCOOTER
# 1522  2016.0        jan  1/1/2016   NaN      THREE WHEELER (PASSENGER)
# 2294  2017.0        jan  1/1/2017   NaN    EDUCATIONAL INSTITUTION BUS
# 2301  2017.0        jan  1/1/2017   NaN                M-CYCLE/SCOOTER
# ...

# %%
df.loc[(df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0])) &
       (df["Vehicle_Type"] == "Institution Bus"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                991
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#         Year Month_Name      Date State                      Vehicle_Class  \
# 13    2014.0        jan  1/1/2014   NaN                    M-CYCLE/SCOOTER
# 19    2014.0        jan  1/1/2014   NaN          THREE WHEELER (PASSENGER)
# 774   2015.0        jan  1/1/2015   NaN                    M-CYCLE/SCOOTER
# 775   2015.0        jan  1/1/2015   NaN      M-CYCLE/SCOOTER-WITH SIDE CAR
# 782   2015.0        jan  1/1/2015   NaN          THREE WHEELER (PASSENGER)
# 1514  2016.0        jan  1/1/2016   NaN                    M-CYCLE/SCOOTER
# 1522  2016.0        jan  1/1/2016   NaN          THREE WHEELER (PASSENGER)
# 2301  2017.0        jan  1/1/2017   NaN                    M-CYCLE/SCOOTER
# 2307  2017.0        jan  1/1/2017   NaN          THREE WHEELER (PASSENGER)
# 3083  2018.0        jan  1/1/2018   NaN                    M-CYCLE/SCOOTER
# 3084  2018.0        jan  1/1/2018   NaN      M-CYCLE/SCOOTER-WITH SIDE CAR
# ...

# %%
df.loc[(df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0])) &
       (df["Vehicle_Type"] == "2W_Personal"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                734
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df.loc[(df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0])) &
       (df["Vehicle_Category"] == "2-Wheelers"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                721
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df.loc[(df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0])) &
       (df["Vehicle_Category"] == "3-Wheelers"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                453
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df.loc[(df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0])) &
       (df["Vehicle_Category"] == "4-Wheelers"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                249
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#          Year Month_Name      Date State                      Vehicle_Class  \
# 8466   2024.0        jan  1/1/2024   NaN                      E-RICKSHAW(P)
# 8467   2024.0        jan  1/1/2024   NaN           E-RICKSHAW WITH CART (G)
# 8471   2024.0        jan  1/1/2024   NaN                         LUXURY CAB
# 8473   2024.0        jan  1/1/2024   NaN                    M-CYCLE/SCOOTER
# 8474   2024.0        jan  1/1/2024   NaN      M-CYCLE/SCOOTER-WITH SIDE CAR
# 8475   2024.0        jan  1/1/2024   NaN                              MOPED
# 8476   2024.0        jan  1/1/2024   NaN                          MOTOR CAB
# 8477   2024.0        jan  1/1/2024   NaN                          MOTOR CAR
# 8478   2024.0        jan  1/1/2024   NaN  MOTOR CYCLE/SCOOTER-USED FOR HIRE
# 8479   2024.0        jan  1/1/2024   NaN        MOTORISED CYCLE (CC > 25CC)
# 8483   2024.0        jan  1/1/2024   NaN              THREE WHEELER (GOODS)
# ...

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "mar"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                228
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "feb"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                207
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df[df["State"].isna()].tail(50)
# Out:
#          Year Month_Name       Date State           Vehicle_Class  \
# 79060  2022.0        oct  10/1/2022   NaN                     BUS
# 79081  2022.0        oct  10/1/2022   NaN                OMNI BUS
# 79082  2022.0        oct  10/1/2022   NaN  OMNI BUS (PRIVATE USE)
# 79833  2023.0        oct  10/1/2023   NaN                     BUS
# 79851  2023.0        oct  10/1/2023   NaN                OMNI BUS
# 79852  2023.0        oct  10/1/2023   NaN  OMNI BUS (PRIVATE USE)
# 80694  2014.0        nov  11/1/2014   NaN                     BUS
# 80707  2014.0        nov  11/1/2014   NaN                OMNI BUS
# 81441  2015.0        nov  11/1/2015   NaN                     BUS
# 81453  2015.0        nov  11/1/2015   NaN                OMNI BUS
# 82210  2016.0        nov  11/1/2016   NaN                     BUS
# 82222  2016.0        nov  11/1/2016   NaN                OMNI BUS
# 82989  2017.0        nov  11/1/2017   NaN                     BUS
# ...

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "oct"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                185
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "nov"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                163
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "dec"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                141
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#          Year Month_Name      Date State                      Vehicle_Class  \
# 8466   2024.0        jan  1/1/2024   NaN                      E-RICKSHAW(P)
# 8467   2024.0        jan  1/1/2024   NaN           E-RICKSHAW WITH CART (G)
# 8471   2024.0        jan  1/1/2024   NaN                         LUXURY CAB
# 8473   2024.0        jan  1/1/2024   NaN                    M-CYCLE/SCOOTER
# 8474   2024.0        jan  1/1/2024   NaN      M-CYCLE/SCOOTER-WITH SIDE CAR
# 8475   2024.0        jan  1/1/2024   NaN                              MOPED
# 8476   2024.0        jan  1/1/2024   NaN                          MOTOR CAB
# 8477   2024.0        jan  1/1/2024   NaN                          MOTOR CAR
# 8478   2024.0        jan  1/1/2024   NaN  MOTOR CYCLE/SCOOTER-USED FOR HIRE
# 8479   2024.0        jan  1/1/2024   NaN        MOTORISED CYCLE (CC > 25CC)
# 8483   2024.0        jan  1/1/2024   NaN              THREE WHEELER (GOODS)
# ...

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "apr"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                120
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "may"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month_Name            0
# Date                  0
# State                99
# Vehicle_Class         0
# Vehicle_Category      0
# Vehicle_Type          0
# EV_Sales_Quantity     0
# dtype: int64

# %%
df[df["State"].isna()].tail(50)
# Out:
#          Year Month_Name      Date State           Vehicle_Class  \
# 54314  2021.0        jul  7/1/2021   NaN                OMNI BUS
# 55084  2022.0        jul  7/1/2022   NaN                     BUS
# 55103  2022.0        jul  7/1/2022   NaN                OMNI BUS
# 55104  2022.0        jul  7/1/2022   NaN  OMNI BUS (PRIVATE USE)
# 55871  2023.0        jul  7/1/2023   NaN                     BUS
# 55889  2023.0        jul  7/1/2023   NaN                OMNI BUS
# 55890  2023.0        jul  7/1/2023   NaN  OMNI BUS (PRIVATE USE)
# 56738  2014.0        aug  8/1/2014   NaN                     BUS
# 56751  2014.0        aug  8/1/2014   NaN                OMNI BUS
# 57488  2015.0        aug  8/1/2015   NaN                     BUS
# 57501  2015.0        aug  8/1/2015   NaN                OMNI BUS
# 58252  2016.0        aug  8/1/2016   NaN                     BUS
# 58265  2016.0        aug  8/1/2016   NaN                OMNI BUS
# ...

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "sep"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month_Name            0
# Date                  0
# State                77
# Vehicle_Class         0
# Vehicle_Category      0
# Vehicle_Type          0
# EV_Sales_Quantity     0
# dtype: int64

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "aug"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month_Name            0
# Date                  0
# State                56
# Vehicle_Class         0
# Vehicle_Category      0
# Vehicle_Type          0
# EV_Sales_Quantity     0
# dtype: int64

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "jul"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month_Name            0
# Date                  0
# State                34
# Vehicle_Class         0
# Vehicle_Category      0
# Vehicle_Type          0
# EV_Sales_Quantity     0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#          Year Month_Name      Date State                      Vehicle_Class  \
# 8466   2024.0        jan  1/1/2024   NaN                      E-RICKSHAW(P)
# 8467   2024.0        jan  1/1/2024   NaN           E-RICKSHAW WITH CART (G)
# 8471   2024.0        jan  1/1/2024   NaN                         LUXURY CAB
# 8473   2024.0        jan  1/1/2024   NaN                    M-CYCLE/SCOOTER
# 8474   2024.0        jan  1/1/2024   NaN      M-CYCLE/SCOOTER-WITH SIDE CAR
# 8475   2024.0        jan  1/1/2024   NaN                              MOPED
# 8476   2024.0        jan  1/1/2024   NaN                          MOTOR CAB
# 8477   2024.0        jan  1/1/2024   NaN                          MOTOR CAR
# 8478   2024.0        jan  1/1/2024   NaN  MOTOR CYCLE/SCOOTER-USED FOR HIRE
# 8479   2024.0        jan  1/1/2024   NaN        MOTORISED CYCLE (CC > 25CC)
# 8483   2024.0        jan  1/1/2024   NaN              THREE WHEELER (GOODS)
# ...

# %%
df.loc[(df["Vehicle_Category"] == "Bus") &
      (df["Vehicle_Type"] == "Bus") &
      (df["Month_Name"] == "jun"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month_Name            0
# Date                  0
# State                12
# Vehicle_Class         0
# Vehicle_Category      0
# Vehicle_Type          0
# EV_Sales_Quantity     0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#         Year Month_Name      Date State                      Vehicle_Class  \
# 8466  2024.0        jan  1/1/2024   NaN                      E-RICKSHAW(P)
# 8467  2024.0        jan  1/1/2024   NaN           E-RICKSHAW WITH CART (G)
# 8471  2024.0        jan  1/1/2024   NaN                         LUXURY CAB
# 8473  2024.0        jan  1/1/2024   NaN                    M-CYCLE/SCOOTER
# 8474  2024.0        jan  1/1/2024   NaN      M-CYCLE/SCOOTER-WITH SIDE CAR
# 8475  2024.0        jan  1/1/2024   NaN                              MOPED
# 8476  2024.0        jan  1/1/2024   NaN                          MOTOR CAB
# 8477  2024.0        jan  1/1/2024   NaN                          MOTOR CAR
# 8478  2024.0        jan  1/1/2024   NaN  MOTOR CYCLE/SCOOTER-USED FOR HIRE
# 8479  2024.0        jan  1/1/2024   NaN        MOTORISED CYCLE (CC > 25CC)
# 8483  2024.0        jan  1/1/2024   NaN              THREE WHEELER (GOODS)
# ...

# %%
df.loc[(df["Vehicle_Category"] == "3-Wheelers") &
      (df["Month_Name"] == "jan"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                 0
# Month_Name           0
# Date                 0
# State                8
# Vehicle_Class        0
# Vehicle_Category     0
# Vehicle_Type         0
# EV_Sales_Quantity    0
# dtype: int64

# %%
df.loc[(df["Vehicle_Category"] == "2-Wheelers") &
      (df["Month_Name"] == "jan"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                 0
# Month_Name           0
# Date                 0
# State                3
# Vehicle_Class        0
# Vehicle_Category     0
# Vehicle_Type         0
# EV_Sales_Quantity    0
# dtype: int64

# %%
df.loc[(df["Vehicle_Category"] == "4-Wheelers") &
      (df["Month_Name"] == "jan"), "State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                 0
# Month_Name           0
# Date                 0
# State                0
# Vehicle_Class        0
# Vehicle_Category     0
# Vehicle_Type         0
# EV_Sales_Quantity    0
# dtype: int64
